# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from seagul.plot import smooth_bounded_curve

# %%
save_dir = "./save_1_ppo"
env_save_name = "acrobot"
env_display_name = "Acrobot"
reward_list = []
for i in range(8):
    reward_list.append(pickle.load(open(f"./{save_dir}/{env_save_name}_rewards.pkl{i}", 'rb')))
    
for r in reward_list:
    plt.plot(r)
    
plt.figure()

fig, ax = smooth_bounded_curve(np.array(reward_list).T, 
                               lower_bound_fn = lambda x: np.mean(x)-np.std(x), 
                               upper_bound_fn = lambda x: np.mean(x)+np.std(x), 
                               window=10, 
                               color='k')
ax.grid()
ax.set_title(f"{env_display_name} Reward Curve")
# Out:
# Text(0.5, 1.0, 'Acrobot Reward Curve')

# %%
save_dir = "./save_1"
env_save_name = "inverted_pendulum_swingup"
env_display_name = "Inverted Pendulum"
reward_list = []
for i in range(4):
    reward_list.append(pickle.load(open(f"./{save_dir}/{env_save_name}_rewards.pkl{i}", 'rb')))
    
for r in reward_list:
    plt.plot(r)
    
plt.figure()

fig, ax = smooth_bounded_curve(np.array(reward_list).T, 
                               lower_bound_fn = lambda x: np.mean(x)-np.std(x), 
                               upper_bound_fn = lambda x: np.mean(x)+np.std(x), 
                               window=10, 
                               color='k')
ax.grid()
ax.set_title(f"{env_display_name} Reward Curve")
# Out:
# Text(0.5, 1.0, 'Inverted Pendulum Reward Curve')

# %%
save_dir = "./save_1"
env_save_name = "inverted_double_pendulum_swingup"
env_display_name = "Inverted Double Pendulum"
reward_list = []
for i in range(4):
    reward_list.append(pickle.load(open(f"./{save_dir}/{env_save_name}_rewards.pkl{i}", 'rb')))
    
for r in reward_list:
    plt.plot(r)
    
plt.figure()

fig, ax = smooth_bounded_curve(np.array(reward_list).T, 
                               lower_bound_fn = lambda x: np.mean(x)-np.std(x), 
                               upper_bound_fn = lambda x: np.mean(x)+np.std(x), 
                               window=10, 
                               color='k')
ax.grid()
ax.set_title(f"{env_display_name} Reward Curve")
# Out:
# Text(0.5, 1.0, 'Inverted Double Pendulum Reward Curve')
